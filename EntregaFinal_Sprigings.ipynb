# %% [markdown]
# <font size="+5" color="orange">**Entrega Final**</font>

# %% [markdown]
# <font size="+4" color="white">**Price House DataSet**</font>

# %% [markdown]
# <font size="+2" color="white">**1. Introducción y Objetivo**</font>

# %% [markdown]
# <font size="+2" color="white">
# Introducción: Predicción de Precios de Viviendas
#
# El mercado inmobiliario, un ámbito dinámico y competitivo, presenta desafíos tanto para vendedores como compradores al determinar el precio óptimo de una propiedad. En este proyecto de Data Science, nos sumergimos en el análisis de un conjunto de datos extenso y detallado que contiene información valiosa sobre diversas características de viviendas en el Estado de Washington, USA.
#
# Hipótesis: Se espera que variables como el tamaño del área construida (sqft_living), la presencia de vistas (view) y la condición de la propiedad (condition) tengan un impacto significativo en el precio de las viviendas en el mercado inmobiliario de Washington, USA. A través del análisis de datos y la construcción de un modelo predictivo, buscamos validar la influencia de estas variables en la estimación precisa de los precios de las propiedades.
#
# El objetivo fundamental radica en emplear técnicas de machine learning para desarrollar un modelo predictivo de regresión capaz de estimar con precisión el precio de una vivienda en función de sus atributos. Esta capacidad de predicción tiene una relevancia significativa en el mercado inmobiliario, brindando a vendedores, compradores y profesionales del sector la oportunidad de tomar decisiones informadas y estratégicas al fijar precios competitivos y justos.
#
# La capacidad de predecir los precios de las propiedades sin necesidad de una inspección física profunda permite agilizar el proceso de evaluación y negociación, beneficiando a todas las partes involucradas en transacciones inmobiliarias. Este enfoque, respaldado por análisis de datos y modelos predictivos, se convierte en una herramienta invaluable para aquellos que buscan maximizar ganancias o realizar inversiones inteligentes en el mercado inmobiliario.

# %% [markdown]
# Esta introducción proporciona una visión general del proyecto, destacando la importancia de la predicción de precios de viviendas y cómo esta capacidad puede influir positivamente en las transacciones inmobiliarias.

# %% [markdown]
# <font size="" color="white">
# Esta introducción proporciona una visión general del proyecto, destacando la importancia de la predicción de precios de viviendas y cómo esta capacidad puede influir positivamente en las transacciones inmobiliarias.

# %% [markdown]
# <font size="+2" color="white">
# Explicación Detallada del Dataset
#
# El conjunto de datos utilizado en este proyecto proviene de una recopilación exhaustiva de información sobre propiedades residenciales en el Estado de Washington, USA. Contiene 4600 registros con 18 variables distintas que ofrecen una visión completa de diversas características de las viviendas y sus entornos. Estas variables son fundamentales para comprender y predecir los precios de las propiedades en el mercado inmobiliario.
# <br>
# <br>
# 1.	Fecha (date): Registros que abarcan el periodo entre mayo y julio de 2014.
# 2.	Precio (price): Valor monetario de las viviendas en US$.
# 3.	Dormitorios (bedrooms): Cantidad de dormitorios en cada propiedad.
# 4.	Baños (bathrooms): Cantidad de baños en cada propiedad.
# 5.	Metraje área construida (sqft_living): Área construida en pies cuadrados.
# 6.	Tamaño del terreno (sqft_lot): Tamaño del terreno en pies cuadrados.
# 7.	Cantidad de pisos (floors): Cantidad de pisos que posee la vivienda, con valores discretos que van desde 1 hasta 3.5.
# 8.	Propiedad en costa (waterfront): Variable binaria (1 o 0) que indica si la propiedad está ubicada en la línea costera.
# 9.	Vista de la propiedad (view): Variable que describe el nivel de vista de la propiedad con valores del 1 al 4.
# 10.	Condición de la propiedad (condition):  Evaluación de la condición de la propiedad con valores del 1 al 5.
# 11.	Metraje del ático (sqft_above): Área del ático en pies cuadrados.
# 12.	Metraje sótano (sqft_basement): Área del sótano en pies cuadrados.
# 13.	Año de construcción (yr_built): Año de construcción de la propiedad.
# 14.	Año de renovación (yr_renovated): Año de renovación de la propiedad.
# 15.	Dirección (street)
# 16.	Ciudad (city)
# 17.	Código postal (statezip)
# 18.	País (country)
#
#
# La relevancia de cada variable radica en su capacidad para influir en el precio de las viviendas. Estas características, como tamaño, ubicación, calidad y antigüedad, son factores críticos considerados por compradores, vendedores y profesionales del mercado inmobiliario al establecer precios competitivos y justos para las propiedades. La profundidad y amplitud de los datos permiten un análisis completo que, combinado con técnicas de machine learning, proporciona la base para construir un modelo predictivo robusto y preciso.

# %% [markdown]
# <font size="" color="white">
# Esta explicación detallada presenta las variables del dataset y su importancia en la predicción de precios de viviendas, resaltando cómo estas características son fundamentales en el mercado inmobiliario.

# %% [markdown]
# <font size="+2" color="white">
# Definición del Objetivo: Predicción Precisa de Precios de Viviendas
#
# El propósito fundamental de este proyecto radica en emplear técnicas de machine learning para desarrollar un modelo predictivo capaz de estimar con precisión el precio de las viviendas en el mercado inmobiliario basándose en sus características específicas. Utilizando un conjunto de datos detallado que abarca información diversa sobre propiedades residenciales en el Estado de Washington, USA, se busca crear un modelo que pueda generalizar y predecir con exactitud los precios de las viviendas en función de factores clave como el tamaño, la ubicación, la cantidad de habitaciones, entre otros.
#
# El enfoque se centra en aplicar algoritmos de regresión, específicamente utilizando un modelo de regresión lineal, sobre variables como el metraje de construcción, el número de dormitorios y baños, la ubicación geográfica y otros atributos relevantes para el mercado inmobiliario. La meta es lograr un modelo robusto y preciso que sea capaz de realizar predicciones confiables de los precios de las viviendas, lo que proporcionaría una herramienta valiosa tanto para vendedores que buscan establecer precios competitivos como para compradores interesados en valorar una propiedad de manera justa y precisa.
#
# La utilidad de este modelo predictivo radica en su capacidad para agilizar el proceso de valoración de propiedades y proporcionar estimaciones rápidas y precisas, ofreciendo a los profesionales del mercado inmobiliario y a los potenciales compradores una herramienta efectiva para la toma de decisiones informadas y estratégicas.

# %% [markdown]
# <font size="" color="white">
# Esta definición clara del objetivo establece la meta principal del proyecto: desarrollar un modelo de machine learning que pueda predecir con precisión los precios de las viviendas basándose en sus características, y destaca la importancia y utilidad práctica de este modelo en el mercado inmobiliario.

# %% [markdown]
# <font size="+2" color="white">**2. Análisis Exploratorio de Datos (EDA)**</font>

# %% [markdown]
# Identificar y tratar valores nulos, duplicados y atípicos es crucial para garantizar la calidad de tus datos y la efectividad de tu modelo.

# %%
# Importo las librerías y las renombro
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
mpl.style.use('bmh')
# Libreria para estimar regresión
import statsmodels.formula.api as sm
from sklearn.model_selection import train_test_split
# Librería para métricas
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from sklearn.decomposition import PCA
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
# Levanto data
url = 'https://raw.githubusercontent.com/NicholasSprigings/DataScience_Sprigings_Entrega5ML/main/data.csv'
df = pd.read_csv(url, sep = ',')

# %% [markdown]
# <font size="+2" color="white">**Variable Target: price**</font>
# <br><br>
# La variable objetivo es de tipo numérica, por lo que el modelo a desarrollar será de tipo Aprendizaje Supervisado: Comencare utilizando un modelo de Regresión.

# %%
# verifico los valores en cero en la variable target price para el df original
df[df['price']==0]
# Out:
#                      date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 4354  2014-05-05 00:00:00    0.0       3.0       1.75         1490     10125
# 4356  2014-05-05 00:00:00    0.0       4.0       2.75         2600      5390
# 4357  2014-05-05 00:00:00    0.0       6.0       2.75         3200      9200
# 4358  2014-05-06 00:00:00    0.0       5.0       3.50         3480     36615
# 4361  2014-05-07 00:00:00    0.0       5.0       1.50         1500      7112
# 4362  2014-05-07 00:00:00    0.0       4.0       4.00         3680     18804
# 4374  2014-05-09 00:00:00    0.0       2.0       2.50         2200    188200
# 4376  2014-05-09 00:00:00    0.0       4.0       2.25         2170     10500
# 4382  2014-05-12 00:00:00    0.0       5.0       4.50         4630      6324
# 4383  2014-05-13 00:00:00    0.0       5.0       4.00         4430      9000
# 4385  2014-05-13 00:00:00    0.0       4.0       4.50         5030     11023
# ...

# %%
df = df[df['price'] > 100]
variable_target = df['price']
# Metodo IQR
primer_cuartil = variable_target.quantile(0.25)
tercer_cuartil = variable_target.quantile(0.75)
rango_intercuartilico = tercer_cuartil - primer_cuartil

# Limites:
limite_inf = primer_cuartil - (1 * rango_intercuartilico)
limite_sup = tercer_cuartil + (1 * rango_intercuartilico)

print(limite_inf,limite_sup,rango_intercuartilico)
# Out:
# -4971.428570999997 988735.7142855 331235.7142855

# %%
# Identifico outliers:
df['Outlier_IQR'] = np.where((df['price'] < limite_inf) | (df['price'] > limite_sup),1,0)
df['Outlier_IQR'].value_counts()
# Out:
# 0    4198
# 1     353
# Name: Outlier_IQR, dtype: int64

# %%
# Creo mi DF sin Outliers
df_sin_outliers = df[df['Outlier_IQR']==0]

# %%
# Agrego la columna de índice como una columna llamada "Index" al DataFrame
df_sin_outliers = df_sin_outliers.assign(Index=df_sin_outliers.index)
print(df_sin_outliers.shape)
# Out:
# (4198, 20)

# %% [markdown]
# <font size="" color="white">
# Lo que realizo arriba es comenzar a desarrollar el analisis quitando los outliers y los valores de la variable target que estan en cero. Como no son demasiados y el precio de una propiedad que se vende nunca podría ser de $0 los elimino.

# %%
df_sin_outliers.head(5)
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00  313000.0       3.0       1.50         1340      7912
# 2  2014-05-02 00:00:00  342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00  420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00  550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00  490000.0       2.0       1.00          880      6380
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
# 5     1.0           0     0          3         880              0      1938
#
# ...

# %%
(df_sin_outliers.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4198 entries, 0 to 4599
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4198 non-null   object
#  1   price          4198 non-null   float64
#  2   bedrooms       4198 non-null   float64
#  3   bathrooms      4198 non-null   float64
#  4   sqft_living    4198 non-null   int64
#  5   sqft_lot       4198 non-null   int64
#  6   floors         4198 non-null   float64
#  7   waterfront     4198 non-null   int64
#  8   view           4198 non-null   int64
#  9   condition      4198 non-null   int64
#  10  sqft_above     4198 non-null   int64
#  11  sqft_basement  4198 non-null   int64
#  12  yr_built       4198 non-null   int64
#  13  yr_renovated   4198 non-null   int64
#  14  street         4198 non-null   object
#  15  city           4198 non-null   object
#  16  statezip       4198 non-null   object
# ...

# %%
(df_sin_outliers.describe())
# Out:
#                price     bedrooms    bathrooms  sqft_living      sqft_lot  \
# count    4198.000000  4198.000000  4198.000000  4198.000000  4.198000e+03
# mean   471901.475729     3.337542     2.071641  1994.385422  1.427446e+04
# std    196120.579962     0.875187     0.696457   772.079919  3.570649e+04
# min      7800.000000     1.000000     0.750000   370.000000  6.380000e+02
# 25%    315000.000000     3.000000     1.750000  1420.000000  5.000000e+03
# 50%    441375.000000     3.000000     2.250000  1900.000000  7.521500e+03
# 75%    600000.000000     4.000000     2.500000  2460.000000  1.049575e+04
# max    988500.000000     9.000000     5.750000  5960.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4198.000000  4198.000000  4198.000000  4198.000000  4198.000000
# mean      1.487851     0.003335     0.158647     3.442354  1716.158885
# std       0.537243     0.057659     0.613241     0.667777   728.663967
# ...

# %% [markdown]
# <font size="" color="white">
# Estos métodos nos permitirán realizar una revisión inicial y comprender la composición y la estructura del dataset, así como la naturaleza de sus variables.

# %% [markdown]
# Estas visualizaciones nos ayudarán a comprender mejor la distribución de los datos y las relaciones entre variables

# %% [markdown]
# <font size="+2" color="white">**Estudio de Variable Target: price**</font>
#
# A continuación se presentarán algunas estadísticas para entender el comportamiento, formato y distribución de esta variable.

# %%
variable_target = df_sin_outliers['price']
variable_target.describe()
# Out:
# count      4198.000000
# mean     471901.475729
# std      196120.579962
# min        7800.000000
# 25%      315000.000000
# 50%      441375.000000
# 75%      600000.000000
# max      988500.000000
# Name: price, dtype: float64

# %%
variable_target = df_sin_outliers['price']
variable_target.describe().round(0)
# Out:
# count      4198.0
# mean     471901.0
# std      196121.0
# min        7800.0
# 25%      315000.0
# 50%      441375.0
# 75%      600000.0
# max      988500.0
# Name: price, dtype: float64

# %%
# Calculo algunas medidas que voy a utilizar
media = variable_target.mean()
mediana = variable_target.median()
primer_cuartil = variable_target.quantile(0.25)
tercer_cuartil = variable_target.quantile(0.75)

# Histograma variable target: price
plt.figure()
sns.histplot(data = df_sin_outliers,
             x = 'price',
             bins = 30,
             alpha = 0.25,
             kde = True,
             stat='probability')
plt.axvline(x = media,
            color = 'red',
            linestyle = '-',
            label = 'Promedio',
            linewidth = 3)
plt.axvline(x = mediana,
            color = '#11B613',
            linestyle = '-',
            label = 'Mediana',
            linewidth = 3)
plt.axvline(x = primer_cuartil,
            color = 'black',
            linestyle = '--',
            label = 'Primer Cuartil',
            linewidth = 2)
plt.axvline(x = tercer_cuartil,
            color = 'black',
            linestyle = '--',
            label = 'Tercer Cuartil',
            linewidth = 2)

plt.legend()
plt.title('Distribución de price')
# Out:
# Text(0.5, 1.0, 'Distribución de price')

# %% [markdown]
# Interpretación: Podemos observar que la variable tiene una distribución sesgada hacia la derecha y al ser la mediana menor que el promedio confirma esta distribución con una tendencia hacia valores más altos lo que nos indica la presencia de valores atípicos en el extremo derecho lo que podría estar influyendo en esta asimetría.
#
# Utilizare la tecnica de <font size="+2" color="white">**Filter Feature Selection**</font> y lo que hare es calcular el Coeficiente de Correlaciín de cada una de las variables (features) con respecto a mi Variable Target: price
# <br> <br/>
# Este analisis es realizado para ver cuáles son las variables numéricas más relacionadas con la variable target y luego las ordenare de mayor a menor los valores hayados

# %%
# Calculo matriz de correlación
matriz_correlacion = df_sin_outliers.corr(method='pearson', numeric_only=True)
# Selecciono a la variable target para estudiar únicamente correlación con ella
matriz_correlacion_target = matriz_correlacion['price']
# Calculo valor absoluto, para extraer correlaciones más fuertes independientemente de su sentido
matriz_correlacion_target = abs(matriz_correlacion_target)
# Menciono columnas que quiero excluir del análisis de correlación
columnas_a_excluir = ['price', 'Outlier_IQR']
# Las excluyo del análisis
matriz_correlacion_target = matriz_correlacion_target.drop(columns=columnas_a_excluir, index=columnas_a_excluir)
# Ordeno de mayor a menor correlacion
matriz_correlacion_target = matriz_correlacion_target.sort_values(ascending=False)

# %%
# Grafico el top 10 de variables más correlacionadas
matriz_correlacion_target_graficar = matriz_correlacion_target[0:10]
plt.figure(figsize=(10, 6))
plt.barh(matriz_correlacion_target_graficar.index,
         matriz_correlacion_target_graficar.values)
plt.xlabel('Correlación')
plt.title('Correlación con price')
plt.gca().invert_yaxis()
plt.show()

# %%
# Elijo el top 10 de variables más correlacionadas con el target
features_selec = matriz_correlacion_target.index[0:10]
features_selec
# Out:
# Index(['sqft_living', 'sqft_above', 'bathrooms', 'bedrooms', 'floors',
#        'sqft_basement', 'view', 'sqft_lot', 'yr_renovated', 'waterfront'],
#       dtype='object')

# %%
matriz_correlacion = df_sin_outliers[features_selec].corr(method='pearson')
sns.heatmap(abs(matriz_correlacion),
           #cbar=False,
           linewidths = 0.3,
           cmap = 'Reds')
# Out:
# <Axes: >

# %% [markdown]
# <font size="" color="white">
# Con estos gráficos lo que podemos sacar en conclusión es cuales variables numéricas son las que tienen más relación con la variable target para poder realizar un estudio más profundo, lo que puede ayudarte a identificar patrones y entender mejor el dataset.

# %% [markdown]
# <font size="+2" color="white">**3. Preparación de Datos & Modelado**</font>

# %% [markdown]
# # Previo a modelar:
# Realizo chequeo Inicial
# <br>

# %%
# Chequeemos que sean todos números:
tipos = df_sin_outliers[features_selec].dtypes
tipos.groupby(tipos).size()
# Out:
# int64      7
# float64    3
# dtype: int64

# %%
# Chequeemos vacíos:
vacios = df_sin_outliers[features_selec].isnull().sum()
vacios[vacios>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Divido el dataset en dos, una porción de entrenamiento y otra de testeo. Para hacer esta partición, hago una distribución de 70% del total de la muestra para entrenamiento y 30% del total de la muestra para testeo.
# <br>

# %% [markdown]
# <font size="+2" color="white">**TRAIN TEST**</font>

# %%
# Separo usando el paquete sklearn
df_train,df_test = train_test_split(df_sin_outliers,
                                    test_size = 0.3, #Porcentaje de muestra test
                                    random_state = 42) #Semilla

# %%
print('price Promedio en TRAIN')
print(df_train['price'].mean())
print('price Promedio en TEST')
print(df_test['price'].mean())
# Out:
# price Promedio en TRAIN
# 472468.1083356586
# price Promedio en TEST
# 470580.23239679367

# %% [markdown]
# #Modelo 1
# <br>
# Genero el primer modelo utilizando las top 10 variables

# %%
# Ajusto el modelo
model_formula = 'price ~ ' + ' + '.join(df_train[features_selec].columns)
lm1   = sm.ols(formula = model_formula, data = df_train).fit()

# %%
coeficientes = lm1.params
print('Coeficientes:')
print(coeficientes.head(21).round(6))
# Out:
# Coeficientes:
# Intercept        170260.868371
# sqft_living         106.414549
# sqft_above           44.026040
# bathrooms          9583.140503
# bedrooms         -23220.957544
# floors            31439.625483
# sqft_basement        62.388508
# view              22250.402427
# sqft_lot             -0.112979
# yr_renovated          4.821637
# waterfront       111087.376733
# dtype: float64

# %%
pvalores_1 = lm1.pvalues
print('P-Valores:')
print(pvalores_1.head(21).round(6).sort_values(ascending=False))
# Out:
# P-Valores:
# sqft_lot         0.154568
# bathrooms        0.147173
# yr_renovated     0.108772
# waterfront       0.014962
# floors           0.000011
# view             0.000007
# Intercept        0.000000
# sqft_living      0.000000
# sqft_above       0.000000
# bedrooms         0.000000
# sqft_basement    0.000000
# dtype: float64

# %%
# Genero columna de predicciones
df_train['Pred_1'] = lm1.predict(df_train)
df_test['Pred_1'] = lm1.predict(df_test)

# %%
df_train.head()
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 209   2014-05-06 00:00:00  483500.0       4.0        2.5         2740
# 3157  2014-06-23 00:00:00  329900.0       3.0        2.5         2242
# 1263  2014-05-23 00:00:00  661254.0       4.0        4.0         2290
# 1322  2014-05-27 00:00:00  468000.0       2.0        1.0         1160
# 3354  2014-06-25 00:00:00  320000.0       4.0        2.5         2000
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# 209      45732     2.0           0     0          3  ...              0
# 3157      4995     2.0           0     0          3  ...              0
# 1263      6250     1.5           0     0          5  ...            600
# 1322      6000     1.0           0     0          4  ...            300
# 3354     10051     2.0           0     0          3  ...              0
#
#       yr_built  yr_renovated              street          city  statezip  \
# ...

# %%
df_test.head()
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 2909  2014-06-19 00:00:00  607500.0       3.0       3.25         1530
# 2193  2014-06-10 00:00:00  569000.0       5.0       3.00         3670
# 3844  2014-07-02 00:00:00  481015.0       3.0       2.25         1550
# 4064  2014-07-08 00:00:00  542000.0       3.0       1.75         1070
# 319   2014-05-08 00:00:00  258000.0       4.0       1.75         1730
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# 2909      1612     3.0           0     0          3  ...              0
# 2193     10583     1.0           0     0          5  ...           1610
# 3844      5511     2.0           0     0          3  ...              0
# 4064      8030     1.0           0     0          3  ...              0
# 319       8320     1.0           0     0          3  ...            500
#
#       yr_built  yr_renovated                   street              city  \
# ...

# %% [markdown]
# # Modelo 2:
# Genero segundo modelo eliminando las variables con los p-values más altos del modelo anterior donde excluyo las variables con p-values arriba de 0.1

# %%
mantener = pvalores_1.index[pvalores_1<=0.1]
mantener = mantener[mantener != 'Intercept']
mantener
# Out:
# Index(['sqft_living', 'sqft_above', 'bedrooms', 'floors', 'sqft_basement',
#        'view', 'waterfront'],
#       dtype='object')

# %%
# Ajusto el modelo
model_formula = 'price ~ ' + ' + '.join(df_train[mantener].columns)
lm2   = sm.ols(formula = model_formula, data = df_train).fit()

# %%
coeficientes = lm2.params
print('Coeficientes:')
print(coeficientes.head(21).round(6))
# Out:
# Coeficientes:
# Intercept        177063.491652
# sqft_living         108.609479
# sqft_above           43.741663
# bedrooms         -21536.432766
# floors            34963.178606
# sqft_basement        64.867816
# view              22523.125501
# waterfront       108736.830801
# dtype: float64

# %%
pvalores = lm2.pvalues
print('P-Valores:')
print(pvalores.head(21).round(6).sort_values(ascending=False))
# Out:
# P-Valores:
# waterfront       0.017258
# view             0.000005
# Intercept        0.000000
# sqft_living      0.000000
# sqft_above       0.000000
# bedrooms         0.000000
# floors           0.000000
# sqft_basement    0.000000
# dtype: float64

# %%
# Genero columna de predicciones
df_train['Pred_2'] = lm2.predict(df_train)
df_test['Pred_2'] = lm2.predict(df_test)

# %%
df_train.head()
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 209   2014-05-06 00:00:00  483500.0       4.0        2.5         2740
# 3157  2014-06-23 00:00:00  329900.0       3.0        2.5         2242
# 1263  2014-05-23 00:00:00  661254.0       4.0        4.0         2290
# 1322  2014-05-27 00:00:00  468000.0       2.0        1.0         1160
# 3354  2014-06-25 00:00:00  320000.0       4.0        2.5         2000
#
#       sqft_lot  floors  waterfront  view  condition  ...  yr_built  \
# 209      45732     2.0           0     0          3  ...      1995
# 3157      4995     2.0           0     0          3  ...      2011
# 1263      6250     1.5           0     0          5  ...      1940
# 1322      6000     1.0           0     0          4  ...      1942
# 3354     10051     2.0           0     0          3  ...      1997
#
#       yr_renovated              street          city  statezip country  \
# ...

# %%
df_test.head()
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 2909  2014-06-19 00:00:00  607500.0       3.0       3.25         1530
# 2193  2014-06-10 00:00:00  569000.0       5.0       3.00         3670
# 3844  2014-07-02 00:00:00  481015.0       3.0       2.25         1550
# 4064  2014-07-08 00:00:00  542000.0       3.0       1.75         1070
# 319   2014-05-08 00:00:00  258000.0       4.0       1.75         1730
#
#       sqft_lot  floors  waterfront  view  condition  ...  yr_built  \
# 2909      1612     3.0           0     0          3  ...      2006
# 2193     10583     1.0           0     0          5  ...      1952
# 3844      5511     2.0           0     0          3  ...      1987
# 4064      8030     1.0           0     0          3  ...      1966
# 319       8320     1.0           0     0          3  ...      1977
#
#       yr_renovated                   street              city  statezip  \
# ...

# %% [markdown]
# # Comparo los dos modelos 1 y 2 de Regresión
# <br>

# %%
# Distribución
# Luego grafico
plt.figure()
# Histograma
sns.histplot(data = df_test,
             x = 'Pred_1',
             bins = 30,
             alpha = 0.25,
             kde = True,
             stat='probability',
            label = 'Modelo 1')
sns.histplot(data  = df_test,
             x = 'Pred_2',
             bins = 30,
             alpha = 0.25,
             kde = True,
             stat='probability',
             color='red',
             label='Modelo 2')

plt.title('Distribución de Predicciones')
plt.xlabel('Predicciones')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %% [markdown]
# Interpretación: Los modelos parecen ser similares pero si lo comparo con el histograma original, la Distribución del las predicciones esta sesgado a la izquierda

# %% [markdown]
# ## Métricas
# Calculemos el R cuadrado y el RMSE.

# %%
rmse_1_test= mean_squared_error(df_test['price'], df_test['Pred_1'], squared=False)
r_squared_1_test = r2_score(df_test['price'], df_test['Pred_1'])
rmse_1_train = mean_squared_error(df_train['price'], df_train['Pred_1'], squared=False)
r_squared_1_train = r2_score(df_train['price'], df_train['Pred_1'])

# %%
rmse_2_test = mean_squared_error(df_test['price'], df_test['Pred_2'], squared=False)
r_squared_2_test = r2_score(df_test['price'], df_test['Pred_2'])
rmse_2_train = mean_squared_error(df_train['price'], df_train['Pred_2'], squared=False)
r_squared_2_train = r2_score(df_train['price'], df_train['Pred_2'])

# %%
metricas = pd.DataFrame(columns=['Poblacion', 'Metrica','Modelo','Valor'])

# %%
datos = [{'Poblacion': 'TEST', 'Metrica': 'RMSE', 'Modelo': 1, 'Valor': rmse_1_test},
         {'Poblacion': 'TRAIN', 'Metrica': 'RMSE', 'Modelo': 1, 'Valor': rmse_1_train},
         {'Poblacion': 'TEST', 'Metrica': 'RMSE', 'Modelo': 2, 'Valor': rmse_2_test},
         {'Poblacion': 'TRAIN', 'Metrica': 'RMSE', 'Modelo': 2, 'Valor': rmse_2_train}]

metricas = pd.concat([metricas, pd.DataFrame(datos)], ignore_index=True)

# %%
# R CUADRADO
datos = [{'Poblacion': 'TEST', 'Metrica': 'R-2', 'Modelo': 1, 'Valor': r_squared_1_test},
         {'Poblacion': 'TRAIN', 'Metrica': 'R-2', 'Modelo': 1, 'Valor': r_squared_1_train},
         {'Poblacion': 'TEST', 'Metrica': 'R-2', 'Modelo': 2, 'Valor': r_squared_2_test},
         {'Poblacion': 'TRAIN', 'Metrica': 'R-2', 'Modelo': 2, 'Valor': r_squared_2_train}]

metricas = pd.concat([metricas, pd.DataFrame(datos)], ignore_index=True)

# %%
metricas
# Out:
#   Poblacion Metrica Modelo          Valor
# 0      TEST    RMSE      1  153717.846042
# 1     TRAIN    RMSE      1  153288.145306
# 2      TEST    RMSE      2  153942.289558
# 3     TRAIN    RMSE      2  153452.062945
# 4      TEST     R-2      1       0.371318
# 5     TRAIN     R-2      1       0.394801
# 6      TEST     R-2      2       0.369481
# 7     TRAIN     R-2      2       0.393506

# %%
fig, ax = plt.subplots(nrows = 2,
                      ncols = 2,
                      figsize = (15,10),
                      sharex = True,
                      sharey = False)

rmse_mod1 = (metricas['Metrica'] == 'RMSE') & (metricas['Modelo'] == 1)
rmse_mod2 = (metricas['Metrica'] == 'RMSE') & (metricas['Modelo'] == 2)
r_2_mod1 = (metricas['Metrica'] == 'R-2') & (metricas['Modelo'] == 1)
r_2_mod2 = (metricas['Metrica'] == 'R-2') & (metricas['Modelo'] == 2)

sns.barplot(data = metricas[rmse_mod1],
            x = 'Metrica',
            y = 'Valor',
            hue = 'Poblacion',
            ax = ax[0, 0])
ax[0, 0].set_title('RMSE - Modelo 1')
ax[0, 0].set_xlabel('Muestra')
ax[0, 0].set_ylabel('RMSE')

sns.barplot(data = metricas[rmse_mod2],
            x = 'Metrica',
            y = 'Valor',
            hue = 'Poblacion',
            ax = ax[0, 1])
ax[0, 1].set_title('RMSE - Modelo 2')
ax[0, 1].set_xlabel('Muestra')
ax[0, 1].set_ylabel('RMSE')

sns.barplot(data = metricas[r_2_mod1],
            x = 'Metrica',
            y = 'Valor',
            hue = 'Poblacion',
            ax = ax[1, 0])
ax[1, 0].set_title('R-2 - Modelo 1')
ax[1, 0].set_xlabel('Muestra')
ax[1, 0].set_ylabel('R-2')

sns.barplot(data = metricas[r_2_mod2],
            x = 'Metrica',
            y = 'Valor',
            hue = 'Poblacion',
            ax = ax[1, 1])
ax[1, 1].set_title('R-2 - Modelo 2')
ax[1, 1].set_xlabel('Muestra')
ax[1, 1].set_ylabel('R-2')
# Out:
# Text(0, 0.5, 'R-2')

# %% [markdown]
# Conclusión: Las tres variables que descarte no estaban sumando ya que los modelos y las métricas son practiamente iguales. Los valores de RMSE y R-2 para ambos modelos en los conjuntos de TEST y TRAIN son bastante similares, lo cual es positivo. No parece haber una gran diferencia entre el rendimiento en ambos conjuntos, lo que sugiere que no hay signos evidentes de overfitting o underfitting.

# %% [markdown]
# <font size="+2" color="white">**Conclusión:**</font>
#
# <font size="" color="white">**Relevancia de las Variables:**</font> Se observó que variables como el tamaño del área construida (sqft_living), la presencia de vistas (view), y la condición de la propiedad (condition) tienen un impacto significativo en los precios de las viviendas.
#
# <font size="" color="white">**Desempeño de los Modelos:**</font> Ambos modelos desarrollados demostraron una capacidad similar para predecir los precios de las viviendas. Aunque se eliminaron algunas variables con p-values más altos en el segundo modelo, los resultados no variaron sustancialmente entre ambos.
#
# <font size="" color="white">**Generalización del Modelo:**</font> La capacidad para generalizar a datos no vistos se observó a través de métricas de evaluación, como el RMSE y R-cuadrado, donde los valores para el conjunto de prueba y de entrenamiento son comparables, indicando una generalización adecuada sin signos evidentes de overfitting o underfitting.
#
# <font size="" color="white">**Utilidad en el Mercado Inmobiliario:**</font> El modelo desarrollado ofrece una herramienta valiosa para tasadores, agentes inmobiliarios y compradores, permitiendo estimar precios sin la necesidad de una inspección física detallada, agilizando el proceso de evaluación y toma de decisiones en transacciones inmobiliarias.
#
# <font size="" color="white">**Importancia del Análisis de Datos en el Mercado Inmobiliario**</font> El uso de técnicas de Data Science y machine learning brinda una ventaja estratégica al sector inmobiliario al permitir tomar decisiones más informadas y estratégicas en la fijación de precios, beneficiando tanto a vendedores como a compradores.

# %% [markdown]
# #Modelo 3:
#
# Genero Modelo de SVM

# %%
# Define las características seleccionadas
features_selec_rf = ['sqft_living', 'sqft_above', 'bathrooms', 'bedrooms', 'floors', 'sqft_basement', 'view', 'sqft_lot', 'yr_renovated', 'waterfront']

# Define el modelo RandomForestRegressor
rf_model = RandomForestRegressor()

# Define los hiperparámetros a buscar
param_grid = {
    'n_estimators': [50, 100, 150],  # Número de árboles en el bosque
    'max_depth': [None, 10, 20, 30],  # Profundidad máxima de los árboles
    'min_samples_split': [2, 5, 10],  # Número mínimo de muestras requeridas para dividir un nodo interno
    'min_samples_leaf': [1, 2, 4]  # Número mínimo de muestras requeridas en cada hoja
}

# Inicializa GridSearchCV
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Entrena el modelo con GridSearchCV
grid_search.fit(df_train[features_selec_rf], df_train['price'])

# Obtiene el mejor modelo
best_rf_model = grid_search.best_estimator_

# Genera predicciones para el conjunto de entrenamiento y de prueba
df_train['Pred_3'] = best_rf_model.predict(df_train[features_selec_rf])
df_test['Pred_3'] = best_rf_model.predict(df_test[features_selec_rf])

# Evalúa el modelo
rmse_train_rf = mean_squared_error(df_train['price'], df_train['Pred_3'], squared=False)
r2_train_rf = r2_score(df_train['price'], df_train['Pred_3'])
rmse_test_rf = mean_squared_error(df_test['price'], df_test['Pred_3'], squared=False)
r2_test_rf = r2_score(df_test['price'], df_test['Pred_3'])

print("Random Forest - Mejores Hiperparámetros encontrados:")
print(grid_search.best_params_)
print("\nDesempeño en el conjunto de entrenamiento:")
print("RMSE:", rmse_train_rf)
print("R^2:", r2_train_rf)
print("\nDesempeño en el conjunto de prueba:")
print("RMSE:", rmse_test_rf)
print("R^2:", r2_test_rf)
# Out:
# Random Forest - Mejores Hiperparámetros encontrados:
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
#
# Desempeño en el conjunto de entrenamiento:
# RMSE: 110372.71264578772
# R^2: 0.6862350055773925
#
# Desempeño en el conjunto de prueba:
# RMSE: 144269.9018585618
# R^2: 0.4462243832325663

# %% [markdown]
# Esto indica que el modelo está realizando un poco peor en el conjunto de prueba en comparación con el conjunto de entrenamiento, lo cual es común. Sin embargo, un R^2 de alrededor de 0.45 en el conjunto de prueba indica que el modelo explica una buena cantidad de la variabilidad en los datos pero aún puede mejorar.

# %%
df_train.head()
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 209   2014-05-06 00:00:00  483500.0       4.0        2.5         2740
# 3157  2014-06-23 00:00:00  329900.0       3.0        2.5         2242
# 1263  2014-05-23 00:00:00  661254.0       4.0        4.0         2290
# 1322  2014-05-27 00:00:00  468000.0       2.0        1.0         1160
# 3354  2014-06-25 00:00:00  320000.0       4.0        2.5         2000
#
#       sqft_lot  floors  waterfront  view  condition  ...              street  \
# 209      45732     2.0           0     0          3  ...  15418 216th Ave NE
# 3157      4995     2.0           0     0          3  ...    Evergreen Way SE
# 1263      6250     1.5           0     0          5  ...    2319 41st Ave SW
# 1322      6000     1.0           0     0          4  ...     3169 NE 85th St
# 3354     10051     2.0           0     0          3  ...   23625 SE 267th Ct
#
#               city  statezip  country Outlier_IQR Index         Pred_1  \
# ...

# %%
df_test.head()
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 2909  2014-06-19 00:00:00  607500.0       3.0       3.25         1530
# 2193  2014-06-10 00:00:00  569000.0       5.0       3.00         3670
# 3844  2014-07-02 00:00:00  481015.0       3.0       2.25         1550
# 4064  2014-07-08 00:00:00  542000.0       3.0       1.75         1070
# 319   2014-05-08 00:00:00  258000.0       4.0       1.75         1730
#
#       sqft_lot  floors  waterfront  view  condition  ...  \
# 2909      1612     3.0           0     0          3  ...
# 2193     10583     1.0           0     0          5  ...
# 3844      5511     2.0           0     0          3  ...
# 4064      8030     1.0           0     0          3  ...
# 319       8320     1.0           0     0          3  ...
#
#                        street              city  statezip  country  \
# 2909          1537 NW 58th St           Seattle  WA 98107      USA
# ...

# %% [markdown]
# # Comparo los tres modelos
# <br>

# %%
# Distribución de predicciones de los tres modelos
plt.figure(figsize=(10, 6))

# Histograma para el modelo 1
sns.histplot(data=df_test, x='Pred_1', bins=30, alpha=0.25, kde=True, stat='probability', label='Modelo 1')

# Histograma para el modelo 2
sns.histplot(data=df_test, x='Pred_2', bins=30, alpha=0.25, kde=True, stat='probability', color='red', label='Modelo 2')

# Histograma para el modelo 3 (SVM)
sns.histplot(data=df_test, x='Pred_3', bins=30, alpha=0.25, kde=True, stat='probability', color='yellow', label='Modelo 3')

plt.title('Distribución de Predicciones de los Tres Modelos')
plt.xlabel('Predicciones')
plt.ylabel('Probabilidad')
plt.legend()
plt.show()

# %% [markdown]
# ## Métricas
# Calculemos el R cuadrado y el RMSE para el modelo 3.

# %%
r2_train_svm = r2_score(df_train['price'], df_train['Pred_3'])
rmse_train_svm = mean_squared_error(df_train['price'], df_train['Pred_3'], squared=False)
r2_test_svm = r2_score(df_test['price'], df_test['Pred_3'])
rmse_test_svm = mean_squared_error(df_test['price'], df_test['Pred_3'], squared=False)
print("Modelo 3")
print("R^2 (Train):", r2_train_svm)
print("RMSE (Train):", rmse_train_svm)
print("R^2 (Test):", r2_test_svm)
print("RMSE (Test):", rmse_test_svm)
# Out:
# Modelo 3
# R^2 (Train): 0.6862350055773925
# RMSE (Train): 110372.71264578772
# R^2 (Test): 0.4462243832325663
# RMSE (Test): 144269.9018585618

# %%
metricas = pd.DataFrame(columns=['Poblacion', 'Metrica','Modelo','Valor'])

# %%
datos = [{'Poblacion': 'TEST', 'Metrica': 'RMSE', 'Modelo': 1, 'Valor': rmse_1_test},
         {'Poblacion': 'TRAIN', 'Metrica': 'RMSE', 'Modelo': 1, 'Valor': rmse_1_train},
         {'Poblacion': 'TEST', 'Metrica': 'RMSE', 'Modelo': 2, 'Valor': rmse_2_test},
         {'Poblacion': 'TRAIN', 'Metrica': 'RMSE', 'Modelo': 2, 'Valor': rmse_2_train},
         {'Poblacion': 'TEST', 'Metrica': 'RMSE', 'Modelo': 3, 'Valor': rmse_test_svm},  # Aquí estaba el error
         {'Poblacion': 'TRAIN', 'Metrica': 'RMSE', 'Modelo': 3, 'Valor': rmse_train_svm}]  # Aquí estaba el error

metricas = pd.concat([metricas, pd.DataFrame(datos)], ignore_index=True)

# %%
# R CUADRADO
datos = [{'Poblacion': 'TEST', 'Metrica': 'R-2', 'Modelo': 1, 'Valor': r_squared_1_test},
         {'Poblacion': 'TRAIN', 'Metrica': 'R-2', 'Modelo': 1, 'Valor': r_squared_1_train},
         {'Poblacion': 'TEST', 'Metrica': 'R-2', 'Modelo': 2, 'Valor': r_squared_2_test},
         {'Poblacion': 'TRAIN', 'Metrica': 'R-2', 'Modelo': 2, 'Valor': r_squared_2_train},
         {'Poblacion': 'TEST', 'Metrica': 'R-2', 'Modelo': 3, 'Valor': r_squared_2_test},
         {'Poblacion': 'TRAIN', 'Metrica': 'R-2', 'Modelo': 3, 'Valor': r_squared_2_train}]

metricas = pd.concat([metricas, pd.DataFrame(datos)], ignore_index=True)

# %%
metricas
# Out:
#    Poblacion Metrica Modelo          Valor
# 0       TEST    RMSE      1  153717.846042
# 1      TRAIN    RMSE      1  153288.145306
# 2       TEST    RMSE      2  153942.289558
# 3      TRAIN    RMSE      2  153452.062945
# 4       TEST    RMSE      3  144269.901859
# 5      TRAIN    RMSE      3  110372.712646
# 6       TEST     R-2      1       0.371318
# 7      TRAIN     R-2      1       0.394801
# 8       TEST     R-2      2       0.369481
# 9      TRAIN     R-2      2       0.393506
# 10      TEST     R-2      3       0.369481
# 11     TRAIN     R-2      3       0.393506

# %%
fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 10), sharex=True, sharey=False)

rmse_mod1 = (metricas['Metrica'] == 'RMSE') & (metricas['Modelo'] == 1)
rmse_mod2 = (metricas['Metrica'] == 'RMSE') & (metricas['Modelo'] == 2)
rmse_mod3 = (metricas['Metrica'] == 'RMSE') & (metricas['Modelo'] == 3)
r_2_mod1 = (metricas['Metrica'] == 'R-2') & (metricas['Modelo'] == 1)
r_2_mod2 = (metricas['Metrica'] == 'R-2') & (metricas['Modelo'] == 2)
r_2_mod3 = (metricas['Metrica'] == 'R-2') & (metricas['Modelo'] == 3)

sns.barplot(data=metricas[rmse_mod1], x='Metrica', y='Valor', hue='Poblacion', ax=ax[0, 0])
ax[0, 0].set_title('RMSE - Modelo 1')
ax[0, 0].set_xlabel('Muestra')
ax[0, 0].set_ylabel('RMSE')

sns.barplot(data=metricas[rmse_mod2], x='Metrica', y='Valor', hue='Poblacion', ax=ax[0, 1])
ax[0, 1].set_title('RMSE - Modelo 2')
ax[0, 1].set_xlabel('Muestra')
ax[0, 1].set_ylabel('RMSE')

sns.barplot(data=metricas[rmse_mod3], x='Metrica', y='Valor', hue='Poblacion', ax=ax[0, 2])  # Agregando el RMSE del modelo 3
ax[0, 2].set_title('RMSE - Modelo 3')  # Titulo para el RMSE del modelo 3
ax[0, 2].set_xlabel('Muestra')
ax[0, 2].set_ylabel('RMSE')

sns.barplot(data=metricas[r_2_mod1], x='Metrica', y='Valor', hue='Poblacion', ax=ax[1, 0])
ax[1, 0].set_title('R-2 - Modelo 1')
ax[1, 0].set_xlabel('Muestra')
ax[1, 0].set_ylabel('R-2')

sns.barplot(data=metricas[r_2_mod2], x='Metrica', y='Valor', hue='Poblacion', ax=ax[1, 1])
ax[1, 1].set_title('R-2 - Modelo 2')
ax[1, 1].set_xlabel('Muestra')
ax[1, 1].set_ylabel('R-2')

sns.barplot(data=metricas[r_2_mod3], x='Metrica', y='Valor', hue='Poblacion', ax=ax[1, 2])  # Agregando el R-2 del modelo 3
ax[1, 2].set_title('R-2 - Modelo 3')  # Titulo para el R-2 del modelo 3
ax[1, 2].set_xlabel('Muestra')
ax[1, 2].set_ylabel('R-2')

plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusión: el Modelo 1 parece ser el mejor entre los tres modelos evaluados en términos de precisión y capacidad de ajuste a los datos.

# %% [markdown]
# <font size="+2" color="white">**PCA y Pipeline**</font>

# %%
# Asegúrate de eliminar las columnas de IDs y el target
df_train_processed = df_train.drop(columns=['Index', 'price', 'date', 'street', 'city', 'statezip', 'country'])
df_test_processed = df_test.drop(columns=['Index', 'price', 'date', 'street', 'city', 'statezip', 'country'])

# %%
# Construye un pipeline con imputación y PCA
pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('pca', PCA())
])

# %%
# Ajusta y transforma los datos de entrenamiento
train_pca = pipeline.fit_transform(df_train_processed)

# %%
# Transforma los datos de prueba
test_pca = pipeline.transform(df_test_processed)

# %%
# Extrae el objeto PCA
pca = pipeline.named_steps['pca']

# %%
plt.figure(figsize=(10, 8))
plt.plot(list(range(df_train_processed.shape[1])), np.cumsum(pca.explained_variance_ratio_), 'r-')
plt.xlabel('Número de Componentes Principales')
plt.ylabel('Varianza Acumulada Explicada')
plt.title('Varianza Acumulada Explicada con PCA')
# Out:
# Text(0.5, 1.0, 'Varianza Acumulada Explicada con PCA')

# %%
# DataFrame de los resultados de PCA
pca_df_train = pd.DataFrame(train_pca, columns=[f'pc_{i}' for i in range(1, train_pca.shape[1] + 1)])
pca_df_train['target'] = df_train['price']

# %%
# Se crea un gráfico de dispersión con etiquetas agrupadas
plt.figure(figsize=(12, 8))
scatter_plot = sns.scatterplot(x='pc_1', y='pc_2', data=pca_df_train, hue='target', palette='viridis', s=100)
plt.xticks(rotation=45, ha='right')
plt.title('PC2 vs PC1 by Target')
plt.show()

# %%
# Grafica pc2 vs pc1 coloreado por el target
sns.lmplot(x='pc_1', y='pc_2', data=pca_df_train, fit_reg=False, height=10)
plt.title('PC2 vs PC1 by Target')
# Out:
# Text(0.5, 1.0, 'PC2 vs PC1 by Target')

# %%
print(f'2 principal components account for {100 * np.sum(pca.explained_variance_ratio_[:2]):.4f}% of the variance.')
# Out:
# 2 principal components account for 98.0098% of the variance.

# %% [markdown]
# <font size="+2" color="white">**Conclusión:**</font>
# El hecho de que dos componentes principales sean capaces de capturar casi toda la variabilidad en los datos sugiere que el PCA ha sido eficaz para resumir la estructura subyacente del conjunto de datos en un formato más simple y manejable. Esto proporciona una base sólida para análisis posteriores y modelado predictivo.
